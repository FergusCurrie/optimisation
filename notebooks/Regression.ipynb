# %%
import cvxpy as cp
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/fergus/data/mldatasets/energy_data/energydata_complete.csv')
y = df.Appliances.to_numpy()
df = df.drop(columns=['date', 'lights', 'Appliances', 'rv1', 'rv2'])
df
# Out:
#               T1       RH_1         T2       RH_2         T3       RH_3  \
# 0      19.890000  47.596667  19.200000  44.790000  19.790000  44.730000
# 1      19.890000  46.693333  19.200000  44.722500  19.790000  44.790000
# 2      19.890000  46.300000  19.200000  44.626667  19.790000  44.933333
# 3      19.890000  46.066667  19.200000  44.590000  19.790000  45.000000
# 4      19.890000  46.333333  19.200000  44.530000  19.790000  45.000000
# ...          ...        ...        ...        ...        ...        ...
# 19730  25.566667  46.560000  25.890000  42.025714  27.200000  41.163333
# 19731  25.500000  46.500000  25.754000  42.080000  27.133333  41.223333
# 19732  25.500000  46.596667  25.628571  42.768571  27.050000  41.690000
# 19733  25.500000  46.990000  25.414000  43.036000  26.890000  41.290000
# 19734  25.500000  46.600000  25.264286  42.971429  26.823333  41.156667
#
#               T4       RH_4         T5       RH_5  ...       T8       RH_8  \
# 0      19.000000  45.566667  17.166667  55.200000  ...  18.2000  48.900000
# 1      19.000000  45.992500  17.166667  55.200000  ...  18.2000  48.863333
# 2      18.926667  45.890000  17.166667  55.090000  ...  18.2000  48.730000
# 3      18.890000  45.723333  17.166667  55.090000  ...  18.1000  48.590000
# 4      18.890000  45.530000  17.200000  55.090000  ...  18.1000  48.590000
# ...          ...        ...        ...        ...  ...      ...        ...
# 19730  24.700000  45.590000  23.200000  52.400000  ...  24.7000  50.074000
# 19731  24.700000  45.590000  23.230000  52.326667  ...  24.7000  49.790000
# 19732  24.700000  45.730000  23.230000  52.266667  ...  24.7000  49.660000
# 19733  24.700000  45.790000  23.200000  52.200000  ...  24.6625  49.518750
# 19734  24.700000  45.963333  23.200000  52.200000  ...  24.7360  49.736000
#
#               T9     RH_9      T_out  Press_mm_hg     RH_out  Windspeed  \
# 0      17.033333  45.5300   6.600000        733.5  92.000000   7.000000
# 1      17.066667  45.5600   6.483333        733.6  92.000000   6.666667
# 2      17.000000  45.5000   6.366667        733.7  92.000000   6.333333
# 3      17.000000  45.4000   6.250000        733.8  92.000000   6.000000
# 4      17.000000  45.4000   6.133333        733.9  92.000000   5.666667
# ...          ...      ...        ...          ...        ...        ...
# 19730  23.200000  46.7900  22.733333        755.2  55.666667   3.333333
# 19731  23.200000  46.7900  22.600000        755.2  56.000000   3.500000
# 19732  23.200000  46.7900  22.466667        755.2  56.333333   3.666667
# 19733  23.200000  46.8175  22.333333        755.2  56.666667   3.833333
# 19734  23.200000  46.8450  22.200000        755.2  57.000000   4.000000
#
#        Visibility  Tdewpoint
# 0       63.000000   5.300000
# 1       59.166667   5.200000
# 2       55.333333   5.100000
# 3       51.500000   5.000000
# 4       47.666667   4.900000
# ...           ...        ...
# 19730   23.666667  13.333333
# 19731   24.500000  13.300000
# 19732   25.333333  13.266667
# 19733   26.166667  13.233333
# 19734   27.000000  13.200000
#
# [19735 rows x 24 columns]

# %%
A = df.to_numpy()
A.shape
# Out:
# (19735, 24)

# %% [markdown]
# First take the dataset and stack the isntances along the rows of a matrix. In the simple linear regression problem the output y is predicted by weighting each feature. Therefore the goal is to learn $ x $ so that $ y = Ax $.
#
# The easiest solution is $ y= A^{-1}y = A^{-1}Ax$. However this requires $A$ to be invertible - this is clearly not possible with a rectangular matrix

# %%
A.shape, y.shape
# Out:
# ((19735, 24), (19735,))

# %% [markdown]
# The next solution is using ordinary least squares :
#
# $$ x= (A^T A)^{-1} A^T b$$
#
# $A^TA$ is psd so invertible.
#
# To measure the fit can do use the l2 norm on the residual: $||Ax - y||_2^2$

# %%
x = np.linalg.inv(A.T @ A) @ A.T @ y
value = np.linalg.norm(A @ x - y, ord=2) ** 2
value, x
# Out:
# (177062001.4005222,
#  array([  0.3823243 ,  16.07934864, -20.28270385, -14.39113808,
#          25.3971245 ,   5.0731454 ,   2.94270269,   1.92969736,
#          -0.048628  ,   0.24076017,   7.68446588,   0.34940726,
#           1.0795233 ,  -1.82174965,  10.22720751,  -5.90933933,
#         -21.99612932,  -1.5234603 , -10.49278327,   0.15934105,
#          -0.87379371,   2.17287998,   0.17570575,   4.87375311]))

# %% [markdown]
# <br>
# This ordinary least squares solution is the analytical solution of the optimisation problem:
#
# \begin{align*}
# \text{minimize } & ||Ax-y||_2^2
# \end{align*}
#
# To veryify this;

# %%
# ValueError: Incompatible dimensions (19735, 24) (19735, 1)
x = cp.Variable(24)
obj = cp.Minimize(cp.norm(A @ x - y, 2) ** 2)
problem = cp.Problem(obj)
problem.solve(solver=cp.SCS,verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 27 09:30:05 PM: Your problem has 24 variables, 0 constraints, and 0 parameters.
# (CVXPY) Apr 27 09:30:05 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 27 09:30:05 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 27 09:30:05 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:30:05 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 27 09:30:05 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 27 09:30:05 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 27 09:30:05 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 27 09:30:05 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 27 09:30:05 PM: Applying reduction SCS
# (CVXPY) Apr 27 09:30:05 PM: Finished problem compilation (took 8.842e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:30:05 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 25, constraints m: 19736
# cones: 	  q: soc vars: 19736, qsize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 473459, nnz(P): 1
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.33e+04  5.02e-01  6.68e+03  3.34e+03  1.00e-01  6.77e-02
#    250| 1.17e+18  2.62e+17  3.84e+23  1.92e+23  5.41e+03  2.86e-01
#    500| 1.30e+17  1.48e+16  4.28e+22  2.14e+22  6.70e+04  5.04e-01
#    750| 8.71e+15  4.80e+14  2.86e+21  1.43e+21  1.00e+06  7.21e-01
#   1000| 6.02e-01  6.32e-02  1.97e+05  1.77e+08  1.00e+06  9.25e-01
#   1025| 1.79e-08  6.38e-02  5.08e-02  1.77e+08  1.00e+06  9.45e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 9.46e-01s = setup: 6.47e-02s + solve: 8.81e-01s
# 	 lin-sys: 7.10e-01s, cones: 3.33e-02s, accel: 9.65e-03s
# ------------------------------------------------------------------
# objective = 177062001.431826
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:30:06 PM: Problem status: optimal
# (CVXPY) Apr 27 09:30:06 PM: Optimal value: 1.771e+08
# (CVXPY) Apr 27 09:30:06 PM: Compilation took 8.842e-02 seconds
# (CVXPY) Apr 27 09:30:06 PM: Solver (including time spent in interface) took 9.469e-01 seconds
# 177062001.40052217

# %%
problem.value, x.value
# Out:
# (177062001.40052217,
#  array([  0.38232408,  16.07934861, -20.28270368, -14.39113802,
#          25.39712449,   5.07314541,   2.9427027 ,   1.92969732,
#          -0.0486282 ,   0.24076017,   7.68446585,   0.34940726,
#           1.07952304,  -1.82174961,  10.22720758,  -5.90933937,
#         -21.99612883,  -1.52346029, -10.49278323,   0.15934105,
#          -0.87379372,   2.17287998,   0.17570575,   4.87375307]))

# %% [markdown]
# same result as before :). interestingly the default solver failed which is why i'm using SCS

# %% [markdown]
# <br>
#
# # Ridge Regression
#
# This extension of the least squares problem adds a penalty term to regularise the weight vector $x$.
#
# \begin{align*}
# \text{minimize } & ||Ax-y||_2^2 + \beta ||x||_2^2
# \end{align*}

# %%
# ValueError: Incompatible dimensions (19735, 24) (19735, 1)
x = cp.Variable(24)
obj = cp.Minimize(cp.norm(A @ x - y, 2)**2 + 10*(cp.norm(x, 2)**2))
#constraint = [beta >= 0.00001]
problem = cp.Problem(obj, constraint)
problem.solve(solver=cp.SCS,verbose=True)
problem.value, x.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 27 09:39:15 PM: Your problem has 25 variables, 1 constraints, and 0 parameters.
# (CVXPY) Apr 27 09:39:15 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 27 09:39:15 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 27 09:39:15 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:39:15 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 27 09:39:15 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 27 09:39:15 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 27 09:39:15 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 27 09:39:15 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 27 09:39:15 PM: Applying reduction SCS
# (CVXPY) Apr 27 09:39:15 PM: Finished problem compilation (took 9.355e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:39:15 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 27, constraints m: 19762
# cones: 	  l: linear vars: 1
# 	  q: soc vars: 19761, qsize: 2
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 473485, nnz(P): 2
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.35e+04  8.51e+00  8.73e+03  4.37e+03  1.00e-01  6.69e-02
#    250| 2.21e+18  5.37e+17  6.75e+23  3.38e+23  3.05e+02  2.79e-01
#    500| 2.04e+18  1.05e+18  6.58e+23  3.30e+23  9.76e+02  4.83e-01
#    750| 2.01e+18  3.61e+17  6.56e+23  3.29e+23  9.76e+02  6.80e-01
#   1000| 2.00e+18  6.80e+16  6.55e+23  3.28e+23  9.76e+02  8.79e-01
#   1100| 1.12e-05  2.66e-04  3.65e+00  1.77e+08  3.12e+03  9.65e-01
# ------------------------------------------------------------------
# status:  solved
# timings: total: 9.65e-01s = setup: 6.40e-02s + solve: 9.01e-01s
# 	 lin-sys: 7.42e-01s, cones: 3.40e-02s, accel: 1.12e-02s
# ------------------------------------------------------------------
# objective = 177085831.762325
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:39:16 PM: Problem status: optimal
# (CVXPY) Apr 27 09:39:16 PM: Optimal value: 1.771e+08
# (CVXPY) Apr 27 09:39:16 PM: Compilation took 9.355e-02 seconds
# (CVXPY) Apr 27 09:39:16 PM: Solver (including time spent in interface) took 9.661e-01 seconds
# (177085829.92423603,
#  array([  0.3604498 ,  16.05707142, -20.20156272, -14.35509732,
#          25.3572786 ,   5.07084874,   2.92447014,   1.92301673,
#          -0.07037059,   0.24103363,   7.66385249,   0.34875621,
#           1.05639943,  -1.82165379,  10.21043017,  -5.90746953,
#         -21.92411421,  -1.52556789, -10.44524224,   0.15834116,
#          -0.86789639,   2.1734008 ,   0.17560868,   4.83820786]))

# %% [markdown]
# Very little difference in the optimal value and solution. I think i'll redo this at some point in the future with a different dataset. The magnitude of the loss is so big that regularisation isn't impactful.

# %% [markdown]
# <br>
#
# # Lasso Regression
#
# This extension of the least squares problem uses the l1 norm to regularise $x$.
#
# \begin{align*}
# \text{minimize } & ||Ax-y||_2^2 + \beta ||x||_1
# \end{align*}

# %%
# ValueError: Incompatible dimensions (19735, 24) (19735, 1)
x = cp.Variable(24)
obj = cp.Minimize(cp.norm(A @ x - y, 2)**2 + 10*(cp.norm(x, 1)))
#constraint = [beta >= 0.00001]
problem = cp.Problem(obj, constraint)
problem.solve(solver=cp.SCS,verbose=True, max_iters=1000)
problem.value, x.value
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Apr 27 09:40:17 PM: Your problem has 25 variables, 1 constraints, and 0 parameters.
# (CVXPY) Apr 27 09:40:17 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 27 09:40:17 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Apr 27 09:40:17 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:40:17 PM: Compiling problem (target solver=SCS).
# (CVXPY) Apr 27 09:40:17 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCS
# (CVXPY) Apr 27 09:40:17 PM: Applying reduction Dcp2Cone
# (CVXPY) Apr 27 09:40:17 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 27 09:40:17 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 27 09:40:17 PM: Applying reduction SCS
# (CVXPY) Apr 27 09:40:17 PM: Finished problem compilation (took 9.308e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:40:17 PM: Invoking solver SCS  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.2 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 50, constraints m: 19785
# cones: 	  l: linear vars: 49
# 	  q: soc vars: 19736, qsize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 1000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 473556, nnz(P): 1
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.34e+04  1.00e+01  3.70e+04 -1.14e+04  1.00e-01  6.74e-02
#    250| 2.14e+17  1.05e+13  8.32e+21  8.25e+21  2.71e+01  2.79e-01
#    500| 2.05e+16  5.74e+14  6.15e+21  3.39e+21  3.49e+02  4.82e-01
#    750| 3.73e+16  4.94e+14  1.17e+22  6.15e+21  3.49e+02  6.79e-01
#   1000| 1.68e+16  1.24e+15  5.35e+21  2.77e+21  1.12e+03  8.83e-01
# ------------------------------------------------------------------
# status:  infeasible (inaccurate - reached max_iters)
# timings: total: 8.83e-01s = setup: 6.44e-02s + solve: 8.19e-01s
# 	 lin-sys: 6.72e-01s, cones: 2.99e-02s, accel: 1.01e-02s
# ------------------------------------------------------------------
# objective = inf (inaccurate)
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 27 09:40:18 PM: Problem status: infeasible_inaccurate
# (CVXPY) Apr 27 09:40:18 PM: Optimal value: inf
# (CVXPY) Apr 27 09:40:18 PM: Compilation took 9.308e-02 seconds
# (CVXPY) Apr 27 09:40:18 PM: Solver (including time spent in interface) took 8.846e-01 seconds
# /home/fergus/.local/lib/python3.10/site-packages/cvxpy/problems/problem.py:1385: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# (inf, None)

# %% [markdown]
# Solver had trouble converging here.
