# %% [markdown]
# # Online Learning
#
# Online Learning and Online Convex Optimization By Shai Shalev-Shwartz is imo best intro resource on this.
#
# Get a sequence of functions to minimise $\{f_t\}$
#
# Want to miminise the cumulative loss
#
# Key points:
#
# - Regret = minimise cumulative loss relative top optimal decision.
#
# ![image.png](attachment:b19e3142-bd9f-492c-aa86-f3cc5c5bd5fa.png)
#
# - Online convex optimisation
#
# ![image.png](attachment:304f9267-0bae-4d0e-9cfb-e96392942f9f.png)
#
# - Follow the leader
#
# ![image.png](attachment:958cc518-acac-49d4-aaa8-ffeb8667f4cb.png)
